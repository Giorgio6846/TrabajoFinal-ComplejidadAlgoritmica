# %%
import pandas as pd
from faker import Faker
import random
from datetime import date, timedelta

df = pd.read_excel("UBIGEODISTRITOS.XLSX")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\Giorgio Mancusi\OneDrive - Universidad Peruana de Ciencias\Grupo 5 - Complejidad Algoritmica\Github\TrabajoFinal-ComplejidadAlgoritmica\Generador\Generador.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Giorgio%20Mancusi/OneDrive%20-%20Universidad%20Peruana%20de%20Ciencias/Grupo%205%20-%20Complejidad%20Algoritmica/Github/TrabajoFinal-ComplejidadAlgoritmica/Generador/Generador.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import random
#       <a href='vscode-notebook-cell:/c%3A/Users/Giorgio%20Mancusi/OneDrive%20-%20Universidad%20Peruana%20de%20Ciencias/Grupo%205%20-%20Complejidad%20Algoritmica/Github/TrabajoFinal-ComplejidadAlgoritmica/Generador/Generador.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from datetime import date, timedelta
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Giorgio%20Mancusi/OneDrive%20-%20Universidad%20Peruana%20de%20Ciencias/Grupo%205%20-%20Complejidad%20Algoritmica/Github/TrabajoFinal-ComplejidadAlgoritmica/Generador/Generador.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> df = pd.read_excel("UBIGEODISTRITOS.XLSX")
#       <a href='vscode-notebook-cell:/c%3A/Users/Giorgio%20Mancusi/OneDrive%20-%20Universidad%20Peruana%20de%20Ciencias/Grupo%205%20-%20Complejidad%20Algoritmica/Github/TrabajoFinal-ComplejidadAlgoritmica/Generador/Generador.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> df
#
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\site-packages\pandas\io\excel\_openpyxl.py:548, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     533 @doc(storage_options=_shared_docs["storage_options"])
#     534 def __init__(
#     535     self,
#     536     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     537     storage_options: StorageOptions = None,
#     538 ) -> None:
#     539     """
#     540     Reader using openpyxl engine.
#     541
#    (...)
#     546     {storage_options}
#     547     """
# --> 548     import_optional_dependency("openpyxl")
#     549     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\Giorgio Mancusi\.conda\envs\baseUpdated\Lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
UbigeoDFStack = df[['NOMBDEP', 'NOMBPROV', 'NOMBDIST']]
UbigeoDFStack
# Out:
#        NOMBDEP     NOMBPROV                NOMBDIST
# 0     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3     AMAZONAS  CHACHAPOYAS                   CHETO
# 4     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...        ...          ...                     ...
# 1869   UCAYALI   PADRE ABAD                 IRAZOLA
# 1870   UCAYALI   PADRE ABAD                CURIMANA
# 1871   UCAYALI   PADRE ABAD                 NESHUYA
# 1872   UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873   UCAYALI        PURUS                   PURUS
#
# [1874 rows x 3 columns]

# %%
ListaDepartamentos = df['NOMBDEP'].unique().tolist()
ListaDepartamentos
# Out:
# ['AMAZONAS',
#  'ANCASH',
#  'APURIMAC',
#  'AREQUIPA',
#  'AYACUCHO',
#  'CAJAMARCA',
#  'CALLAO',
#  'CUSCO',
#  'HUANCAVELICA',
#  'HUANUCO',
#  'ICA',
#  'JUNIN',
#  'LA LIBERTAD',
#  'LAMBAYEQUE',
#  'LIMA',
#  'LORETO',
#  'MADRE DE DIOS',
#  'MOQUEGUA',
#  'PASCO',
#  'PIURA',
#  'PUNO',
#  'SAN MARTIN',
#  'TACNA',
#  'TUMBES',
#  'UCAYALI']

# %%
CodigosUbigeo = df['IDDIST'].unique().tolist()
CodigosUbigeo
# Out:
# [10101,
#  10102,
#  10103,
#  10104,
#  10105,
#  10106,
#  10107,
#  10108,
#  10109,
#  10110,
#  10111,
#  10112,
#  10113,
#  10114,
#  10115,
#  10116,
#  10117,
#  10118,
#  10119,
#  10120,
#  10121,
#  10201,
#  10202,
#  10203,
#  10204,
#  10205,
#  10206,
#  10301,
#  10302,
#  10303,
#  10304,
#  10305,
#  10306,
#  10307,
#  10308,
#  10309,
#  10310,
#  10311,
#  10312,
#  10401,
#  10402,
#  10403,
#  10501,
#  10502,
#  10503,
#  10504,
#  10505,
#  10506,
#  10507,
#  10508,
#  10509,
#  10510,
#  10511,
#  10512,
#  10513,
#  10514,
#  10515,
#  10516,
#  10517,
#  10518,
#  10519,
#  10520,
#  10521,
#  10522,
#  10523,
#  10601,
#  10602,
#  10603,
#  10604,
#  10605,
#  10606,
#  10607,
#  10608,
#  10609,
#  10610,
#  10611,
#  10612,
#  10701,
#  10702,
#  10703,
#  10704,
#  10705,
#  10706,
#  10707,
#  20101,
#  20102,
#  20103,
#  20104,
#  20105,
#  20106,
#  20107,
#  20108,
#  20109,
#  20110,
#  20111,
#  20112,
#  20201,
#  20202,
#  20203,
#  20204,
#  20205,
#  20301,
#  20302,
#  20303,
#  20304,
#  20305,
#  20306,
#  20401,
#  20402,
#  20501,
#  20502,
#  20503,
#  20504,
#  20505,
#  20506,
#  20507,
#  20508,
#  20509,
#  20510,
#  20511,
#  20512,
#  20513,
#  20514,
#  20515,
#  20601,
#  20602,
#  20603,
#  20604,
#  20605,
#  20606,
#  20607,
#  20608,
#  20609,
#  20610,
#  20611,
#  20701,
#  20702,
#  20703,
#  20801,
#  20802,
#  20803,
#  20804,
#  20901,
#  20902,
#  20903,
#  20904,
#  20905,
#  20906,
#  20907,
#  21001,
#  21002,
#  21003,
#  21004,
#  21005,
#  21006,
#  21007,
#  21008,
#  21009,
#  21010,
#  21011,
#  21012,
#  21013,
#  21014,
#  21015,
#  21016,
#  21101,
#  21102,
#  21103,
#  21104,
#  21105,
#  21201,
#  21202,
#  21203,
#  21204,
#  21205,
#  21206,
#  21207,
#  21208,
#  21209,
#  21210,
#  21301,
#  21302,
#  21303,
#  21304,
#  21305,
#  21306,
#  21307,
#  21308,
#  21401,
#  21402,
#  21403,
#  21404,
#  21405,
#  21406,
#  21407,
#  21408,
#  21409,
#  21410,
#  21501,
#  21502,
#  21503,
#  21504,
#  21505,
#  21506,
#  21507,
#  21508,
#  21509,
#  21510,
#  21511,
#  21601,
#  21602,
#  21603,
#  21604,
#  21701,
#  21702,
#  21703,
#  21704,
#  21705,
#  21706,
#  21707,
#  21708,
#  21709,
#  21710,
#  21801,
#  21802,
#  21803,
#  21804,
#  21805,
#  21806,
#  21807,
#  21808,
#  21809,
#  21901,
#  21902,
#  21903,
#  21904,
#  21905,
#  21906,
#  21907,
#  21908,
#  21909,
#  21910,
#  22001,
#  22002,
#  22003,
#  22004,
#  22005,
#  22006,
#  22007,
#  22008,
#  30101,
#  30102,
#  30103,
#  30104,
#  30105,
#  30106,
#  30107,
#  30108,
#  30109,
#  30201,
#  30202,
#  30203,
#  30204,
#  30205,
#  30206,
#  30207,
#  30208,
#  30209,
#  30210,
#  30211,
#  30212,
#  30213,
#  30214,
#  30215,
#  30216,
#  30217,
#  30218,
#  30219,
#  30220,
#  30301,
#  30302,
#  30303,
#  30304,
#  30305,
#  30306,
#  30307,
#  30401,
#  30402,
#  30403,
#  30404,
#  30405,
#  30406,
#  30407,
#  30408,
#  30409,
#  30410,
#  30411,
#  30412,
#  30413,
#  30414,
#  30415,
#  30416,
#  30417,
#  30501,
#  30502,
#  30503,
#  30504,
#  30505,
#  30506,
#  30601,
#  30602,
#  30603,
#  30604,
#  30605,
#  30606,
#  30607,
#  30608,
#  30609,
#  30610,
#  30611,
#  30701,
#  30702,
#  30703,
#  30704,
#  30705,
#  30706,
#  30707,
#  30708,
#  30709,
#  30710,
#  30711,
#  30712,
#  30713,
#  30714,
#  40101,
#  40102,
#  40103,
#  40104,
#  40105,
#  40106,
#  40107,
#  40108,
#  40109,
#  40110,
#  40111,
#  40112,
#  40113,
#  40114,
#  40115,
#  40116,
#  40117,
#  40118,
#  40119,
#  40120,
#  40121,
#  40122,
#  40123,
#  40124,
#  40125,
#  40126,
#  40127,
#  40128,
#  40129,
#  40201,
#  40202,
#  40203,
#  40204,
#  40205,
#  40206,
#  40207,
#  40208,
#  40301,
#  40302,
#  40303,
#  40304,
#  40305,
#  40306,
#  40307,
#  40308,
#  40309,
#  40310,
#  40311,
#  40312,
#  40313,
#  40401,
#  40402,
#  40403,
#  40404,
#  40405,
#  40406,
#  40407,
#  40408,
#  40409,
#  40410,
#  40411,
#  40412,
#  40413,
#  40414,
#  40501,
#  40502,
#  40503,
#  40504,
#  40505,
#  40506,
#  40507,
#  40508,
#  40509,
#  40510,
#  40511,
#  40512,
#  40513,
#  40514,
#  40515,
#  40516,
#  40517,
#  40518,
#  40519,
#  40520,
#  40601,
#  40602,
#  40603,
#  40604,
#  40605,
#  40606,
#  40607,
#  40608,
#  40701,
#  40702,
#  40703,
#  40704,
#  40705,
#  40706,
#  40801,
#  40802,
#  40803,
#  40804,
#  40805,
#  40806,
#  40807,
#  40808,
#  40809,
#  40810,
#  40811,
#  50101,
#  50102,
#  50103,
#  50104,
#  50105,
#  50106,
#  50107,
#  50108,
#  50109,
#  50110,
#  50111,
#  50112,
#  50113,
#  50114,
#  50115,
#  50116,
#  50201,
#  50202,
#  50203,
#  50204,
#  50205,
#  50206,
#  50301,
#  50302,
#  50303,
#  50304,
#  50401,
#  50402,
#  50403,
#  50404,
#  50405,
#  50406,
#  50407,
#  50408,
#  50409,
#  50410,
#  50411,
#  50412,
#  50501,
#  50502,
#  50503,
#  50504,
#  50505,
#  50506,
#  50507,
#  50508,
#  50509,
#  50510,
#  50511,
#  50601,
#  50602,
#  50603,
#  50604,
#  50605,
#  50606,
#  50607,
#  50608,
#  50609,
#  50610,
#  50611,
#  50612,
#  50613,
#  50614,
#  50615,
#  50616,
#  50617,
#  50618,
#  50619,
#  50620,
#  50621,
#  50701,
#  50702,
#  50703,
#  50704,
#  50705,
#  50706,
#  50707,
#  50708,
#  50801,
#  50802,
#  50803,
#  50804,
#  50805,
#  50806,
#  50807,
#  50808,
#  50809,
#  50810,
#  50901,
#  50902,
#  50903,
#  50904,
#  50905,
#  50906,
#  50907,
#  50908,
#  50909,
#  50910,
#  50911,
#  51001,
#  51002,
#  51003,
#  51004,
#  51005,
#  51006,
#  51007,
#  51008,
#  51009,
#  51010,
#  51011,
#  51012,
#  51101,
#  51102,
#  51103,
#  51104,
#  51105,
#  51106,
#  51107,
#  51108,
#  60101,
#  60102,
#  60103,
#  60104,
#  60105,
#  60106,
#  60107,
#  60108,
#  60109,
#  60110,
#  60111,
#  60112,
#  60201,
#  60202,
#  60203,
#  60204,
#  60301,
#  60302,
#  60303,
#  60304,
#  60305,
#  60306,
#  60307,
#  60308,
#  60309,
#  60310,
#  60311,
#  60312,
#  60401,
#  60402,
#  60403,
#  60404,
#  60405,
#  60406,
#  60407,
#  60408,
#  60409,
#  60410,
#  60411,
#  60412,
#  60413,
#  60414,
#  60415,
#  60416,
#  60417,
#  60418,
#  60419,
#  60501,
#  60502,
#  60503,
#  60504,
#  60505,
#  60506,
#  60507,
#  60508,
#  60601,
#  60602,
#  60603,
#  60604,
#  60605,
#  60606,
#  60607,
#  60608,
#  60609,
#  60610,
#  60611,
#  60612,
#  60613,
#  60614,
#  60615,
#  60701,
#  60702,
#  60703,
#  60801,
#  60802,
#  60803,
#  60804,
#  60805,
#  60806,
#  60807,
#  60808,
#  60809,
#  60810,
#  60811,
#  60812,
#  60901,
#  60902,
#  60903,
#  60904,
#  60905,
#  60906,
#  60907,
#  61001,
#  61002,
#  61003,
#  61004,
#  61005,
#  61006,
#  61007,
#  61101,
#  61102,
#  61103,
#  61104,
#  61105,
#  61106,
#  61107,
#  61108,
#  61109,
#  61110,
#  61111,
#  61112,
#  61113,
#  61201,
#  61202,
#  61203,
#  61204,
#  61301,
#  61302,
#  61303,
#  61304,
#  61305,
#  61306,
#  61307,
#  61308,
#  61309,
#  61310,
#  61311,
#  70101,
#  70102,
#  70103,
#  70104,
#  70105,
#  70106,
#  70107,
#  80101,
#  80102,
#  80103,
#  80104,
#  80105,
#  80106,
#  80107,
#  80108,
#  80201,
#  80202,
#  80203,
#  80204,
#  80205,
#  80206,
#  80207,
#  80301,
#  80302,
#  80303,
#  80304,
#  80305,
#  80306,
#  80307,
#  80308,
#  80309,
#  80401,
#  80402,
#  80403,
#  80404,
#  80405,
#  80406,
#  80407,
#  80408,
#  80501,
#  80502,
#  80503,
#  80504,
#  80505,
#  80506,
#  80507,
#  80508,
#  80601,
#  80602,
#  80603,
#  80604,
#  80605,
#  80606,
#  80607,
#  80608,
#  80701,
#  80702,
#  80703,
#  80704,
#  80705,
#  80706,
#  80707,
#  80708,
#  80801,
#  80802,
#  80803,
#  80804,
#  80805,
#  80806,
#  80807,
#  80808,
#  80901,
#  80902,
#  80903,
#  80904,
#  80905,
#  80906,
#  80907,
#  80908,
#  80909,
#  80910,
#  80911,
#  80912,
#  80913,
#  80914,
#  81001,
#  81002,
#  81003,
#  81004,
#  81005,
#  81006,
#  81007,
#  81008,
#  81009,
#  81101,
#  81102,
#  81103,
#  81104,
#  81105,
#  81106,
#  81201,
#  81202,
#  81203,
#  81204,
#  81205,
#  81206,
#  81207,
#  81208,
#  81209,
#  81210,
#  81211,
#  81212,
#  81301,
#  81302,
#  81303,
#  81304,
#  81305,
#  81306,
#  81307,
#  90101,
#  90102,
#  90103,
#  90104,
#  90105,
#  90106,
#  90107,
#  90108,
#  90109,
#  90110,
#  90111,
#  90112,
#  90113,
#  90114,
#  90115,
#  90116,
#  90117,
#  90118,
#  90119,
#  90201,
#  90202,
#  90203,
#  90204,
#  90205,
#  90206,
#  90207,
#  90208,
#  90301,
#  90302,
#  90303,
#  90304,
#  90305,
#  90306,
#  90307,
#  90308,
#  90309,
#  90310,
#  90311,
#  90312,
#  90401,
#  90402,
#  90403,
#  90404,
#  90405,
#  90406,
#  90407,
#  90408,
#  90409,
#  90410,
#  90411,
#  90412,
#  90413,
#  90501,
#  90502,
#  90503,
#  90504,
#  90505,
#  90506,
#  90507,
#  90508,
#  90509,
#  90510,
#  90511,
#  90601,
#  90602,
#  90603,
#  90604,
#  90605,
#  90606,
#  90607,
#  90608,
#  90609,
#  90610,
#  90611,
#  90612,
#  90613,
#  90614,
#  90615,
#  90616,
#  90701,
#  90702,
#  90703,
#  90704,
#  90705,
#  90706,
#  90707,
#  90709,
#  90710,
#  90711,
#  90713,
#  90714,
#  90715,
#  90716,
#  90717,
#  90718,
#  90719,
#  90720,
#  90721,
#  90722,
#  90723,
#  100101,
#  100102,
#  100103,
#  100104,
#  100105,
#  100106,
#  100107,
#  100108,
#  100109,
#  100110,
#  100111,
#  100112,
#  100113,
#  100201,
#  100202,
#  100203,
#  100204,
#  100205,
#  100206,
#  100207,
#  100208,
#  100301,
#  100307,
#  100311,
#  100313,
#  100316,
#  100317,
#  100321,
#  100322,
#  100323,
#  100401,
#  100402,
#  100403,
#  100404,
#  100501,
#  100502,
#  100503,
#  100504,
#  100505,
#  100506,
#  100507,
#  100508,
#  100509,
#  100510,
#  100511,
#  100601,
#  100602,
#  100603,
#  100604,
#  100605,
#  100606,
#  100607,
#  100608,
#  100609,
#  100610,
#  100701,
#  100702,
#  100703,
#  100704,
#  100705,
#  100801,
#  100802,
#  100803,
#  100804,
#  100901,
#  100902,
#  100903,
#  100904,
#  100905,
#  101001,
#  101002,
#  101003,
#  101004,
#  101005,
#  101006,
#  101007,
#  101101,
#  101102,
#  101103,
#  101104,
#  101105,
#  101106,
#  101107,
#  101108,
#  110101,
#  110102,
#  110103,
#  110104,
#  110105,
#  110106,
#  110107,
#  110108,
#  ...]

# %%
fake = Faker('es_ES')

size = 50

def row(num):
        vivienda = num
        direccion = fake.street_name() + str(" ") + str(random.randint(101, 1000))
        tipoVivienda = random.choice(['Casa', 'Apartamento', 'Departamento'])
        material_paredes = random.choice(['Ladrillo', 'Concreto', 'Adobe'])
        material_techo = random.choice(['Teja', 'Techo de Paja', 'Eternit'])
        material_piso = random.choice(['Ceramica', 'Parquet', 'Tierra'])
        cuartos = random.randint(1, 6)
        banos = random.randint(1, 4)
        cocinas = random.randint(1, 2)
        comedores = random.randint(0, 2)
        dormitorios = random.randint(1, cuartos)
        personas_vivienda = random.randint(1, 10)
        jefe_hogar = fake.name()
        ubigeo = random.choice(CodigosUbigeo)
        departamento = df.loc[df['IDDIST'] == ubigeo, 'NOMBDEP'].item()
        provincia = df.loc[df['IDDIST']==ubigeo, 'NOMBPROV'].item()
        distrito = df.loc[df['IDDIST'] == ubigeo, 'NOMBDIST'].item()
        date_time = fake.date_time()
        fecha_censo = (date(2017, 7, 1) + timedelta(days=random.randint(0, 30))).strftime("%d/%m/%Y")
        quien_respondio = jefe_hogar 
    
        data = {
            "vivienda" : vivienda,
            "direccion" : direccion,
            "tipoVivienda" : tipoVivienda,
            "material_paredes" : material_paredes,
            "material_techo" : material_techo,
            "material_piso" : material_piso,
            "cuartos" : cuartos,
            "banos" : banos,
            "cocinas" : cocinas,
            "comedores" : comedores,
            "dormitorios" : dormitorios,
            "personas_vivienda" : personas_vivienda,
            "jefe_hogar" : jefe_hogar,
            "departamento" : departamento,
            "provincia" : provincia,
            "distrito": distrito,
            "date_time" : date_time,
            "ubigeo" : ubigeo,
            "fecha_censo" : fecha_censo,
            "quien_respondio": quien_respondio
        }
    
        return data

def create_rows_faker(num=1):
    output = [row(x) for x in range(num)]

    return output

df_faker = pd.DataFrame(create_rows_faker(50000))
df_faker.to_csv('Dataframe.csv')
df_faker = df_faker.drop(['vivienda'], axis = 1)
df_faker
# Out:
#                            direccion  tipoVivienda material_paredes  \
# 0      Cañada de Duilio Doménech 519          Casa         Ladrillo
# 1         Ronda de Emiliano León 602  Departamento         Ladrillo
# 2           Vial Isaac Casanovas 696  Departamento         Concreto
# 3            Camino Adela Blanca 819  Departamento         Ladrillo
# 4         Plaza Montserrat Ruano 552  Departamento            Adobe
# ...                              ...           ...              ...
# 49995  Avenida Edelmira Higueras 291          Casa            Adobe
# 49996      Plaza Bibiana Cabello 732   Apartamento            Adobe
# 49997    Camino de Norberto Pons 158  Departamento            Adobe
# 49998       Plaza Marciano Salvà 783  Departamento         Ladrillo
# 49999  Pasadizo Begoña Gutierrez 528          Casa         Ladrillo
#
#       material_techo material_piso  cuartos  banos  cocinas  comedores  \
# 0      Techo de Paja        Tierra        1      3        1          2
# 1            Eternit      Ceramica        4      2        2          1
# 2               Teja      Ceramica        2      1        2          1
# 3      Techo de Paja        Tierra        6      2        1          2
# 4               Teja       Parquet        3      1        2          2
# ...              ...           ...      ...    ...      ...        ...
# 49995           Teja        Tierra        5      4        2          1
# 49996           Teja        Tierra        2      2        1          0
# 49997  Techo de Paja        Tierra        2      4        2          1
# 49998  Techo de Paja      Ceramica        6      4        2          1
# 49999  Techo de Paja        Tierra        5      2        1          0
#
#        dormitorios  personas_vivienda                  jefe_hogar  \
# 0                1                  3            Noa Oliva Coello
# 1                2                  2      Lisandro Nieto Pascual
# 2                1                  1         Juan Manuel Revilla
# 3                6                  2          Candela del Tirado
# 4                3                  3         Sonia Ortuño Montes
# ...            ...                ...                         ...
# 49995            3                 10     Rufina Lara Cabo Azcona
# 49996            2                  8  Bernardino Company Nicolás
# 49997            2                  1     Emigdio Domingo Cordero
# 49998            3                  3          Clímaco del Benito
# 49999            2                  2     Eusebia Becerra Guardia
#
#       departamento              provincia      distrito           date_time  \
# 0          UCAYALI                ATALAYA      TAHUANIA 1971-05-24 12:07:13
# 1            CUSCO                ACOMAYO       ACOMAYO 1995-10-16 17:39:29
# 2            PIURA                  PIURA  TAMBO GRANDE 1984-07-16 04:51:35
# 3              ICA                    ICA       OCUCAJE 2015-04-08 07:30:55
# 4         MOQUEGUA  GENERAL SANCHEZ CERRO    LA CAPILLA 2011-11-27 00:20:17
# ...            ...                    ...           ...                 ...
# 49995     AREQUIPA               CAYLLOMA     ICHUPAMPA 1984-07-17 22:47:44
# 49996     APURIMAC             COTABAMBAS    COTABAMBAS 1992-05-22 10:45:50
# 49997  LA LIBERTAD      SANTIAGO DE CHUCO    MOLLEBAMBA 2001-03-03 03:35:38
# 49998         PUNO               AZANGARO     SAN ANTON 2013-07-19 16:48:36
# 49999         PUNO               AZANGARO      SAN JOSE 2005-08-14 03:08:41
#
#        ubigeo fecha_censo             quien_respondio
# 0      250203  20/07/2017            Noa Oliva Coello
# 1       80201  11/07/2017      Lisandro Nieto Pascual
# 2      200114  19/07/2017         Juan Manuel Revilla
# 3      110104  17/07/2017          Candela del Tirado
# 4      180205  04/07/2017         Sonia Ortuño Montes
# ...       ...         ...                         ...
# 49995   40509  12/07/2017     Rufina Lara Cabo Azcona
# 49996   30502  15/07/2017  Bernardino Company Nicolás
# 49997  131004  28/07/2017     Emigdio Domingo Cordero
# 49998  210211  17/07/2017          Clímaco del Benito
# 49999  210212  17/07/2017     Eusebia Becerra Guardia
#
# [50000 rows x 19 columns]
