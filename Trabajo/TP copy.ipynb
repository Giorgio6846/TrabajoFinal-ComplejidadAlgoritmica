# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

ubigeo = pd.read_excel("../Generador/UBIGEODISTRITOS.XLSX")

df = pd.read_csv('../Generador/Dataframe.csv')
df
# Out:
#        Unnamed: 0  vivienda                       direccion  tipoVivienda  \
# 0               0         0  Acceso de Feliciano Alsina 336  Departamento
# 1               1         1            C. Salvador Daza 796   Apartamento
# 2               2         2       Cuesta Candelas Elías 805   Apartamento
# 3               3         3     Acceso Anselma Manrique 177   Apartamento
# 4               4         4   Callejón Jeremías Bastida 773   Apartamento
# ...           ...       ...                             ...           ...
# 49995       49995     49995         Glorieta Rafa Olivé 300  Departamento
# 49996       49996     49996     Alameda Evaristo Hierro 154          Casa
# 49997       49997     49997          Via Lázaro Bonilla 488   Apartamento
# 49998       49998     49998   Cañada de Desiderio Pedro 999  Departamento
# 49999       49999     49999     Cuesta de Ovidio Segura 683  Departamento
#
#       material_paredes material_techo material_piso  cuartos  banos  cocinas  \
# 0             Concreto           Teja       Parquet        6      1        1
# 1             Concreto           Teja        Tierra        1      3        2
# 2             Concreto  Techo de Paja        Tierra        4      2        1
# 3             Concreto  Techo de Paja       Parquet        3      2        2
# 4             Ladrillo           Teja       Parquet        3      3        2
# ...                ...            ...           ...      ...    ...      ...
# 49995         Concreto  Techo de Paja      Ceramica        6      4        2
# 49996            Adobe           Teja       Parquet        4      2        2
# 49997         Ladrillo        Eternit        Tierra        4      3        2
# 49998         Ladrillo           Teja      Ceramica        4      2        1
# 49999         Concreto        Eternit       Parquet        6      4        2
#
#        ...  dormitorios  personas_vivienda                  jefe_hogar  \
# 0      ...            2                  6        Juan Bautista de Luz
# 1      ...            1                  9   Alejandro Segarra-Cabello
# 2      ...            2                  2      Leoncio Carrillo Jerez
# 3      ...            3                  7              Felisa Alemany
# 4      ...            1                 10   Maximiliano Segarra Bauzà
# ...    ...          ...                ...                         ...
# 49995  ...            6                  5           Jordana del Lerma
# 49996  ...            2                  1       Santos Solano Arribas
# 49997  ...            2                  5    Carlota Blázquez Infante
# 49998  ...            4                  2     Débora Segarra Benavent
# 49999  ...            3                  4  Amarilis Alvarado Palomino
#
#        departamento   provincia      distrito            date_time  ubigeo  \
# 0            ANCASH     CARHUAZ   PARIAHUANCA  2017-01-06 06:03:55   20607
# 1             CUSCO        ANTA     ANCAHUASI  1988-07-25 14:39:47   80302
# 2          AYACUCHO     LUCANAS         OCAÑA  2016-03-29 02:52:26   50612
# 3            ANCASH    PALLASCA    SANTA ROSA  1987-12-11 02:15:24   21510
# 4            ANCASH     CORONGO        BAMBAS  2019-10-30 03:25:49   20903
# ...             ...         ...           ...                  ...     ...
# 49995      AREQUIPA  CONDESUYOS      CAYARANI  1972-10-25 02:04:14   40603
# 49996      AREQUIPA    LA UNION     TOMEPAMPA  2005-06-28 21:52:50   40810
# 49997   LA LIBERTAD    TRUJILLO        LAREDO  2007-09-14 00:54:05  130106
# 49998        LORETO    PUTUMAYO  ROSA PANDURO  2001-12-10 22:46:39  160802
# 49999  HUANCAVELICA    ACOBAMBA          ANTA  1987-01-28 19:41:41   90203
#
#        fecha_censo             quien_respondio
# 0       13/07/2017        Juan Bautista de Luz
# 1       12/07/2017   Alejandro Segarra-Cabello
# 2       16/07/2017      Leoncio Carrillo Jerez
# 3       02/07/2017              Felisa Alemany
# 4       23/07/2017   Maximiliano Segarra Bauzà
# ...            ...                         ...
# 49995   02/07/2017           Jordana del Lerma
# 49996   11/07/2017       Santos Solano Arribas
# 49997   07/07/2017    Carlota Blázquez Infante
# 49998   21/07/2017     Débora Segarra Benavent
# 49999   18/07/2017  Amarilis Alvarado Palomino
#
# [50000 rows x 21 columns]

# %%
df1 = df.loc[:,["direccion","departamento","provincia","distrito"]]
df1
# Out:
#                             direccion  departamento   provincia      distrito
# 0      Acceso de Feliciano Alsina 336        ANCASH     CARHUAZ   PARIAHUANCA
# 1                C. Salvador Daza 796         CUSCO        ANTA     ANCAHUASI
# 2           Cuesta Candelas Elías 805      AYACUCHO     LUCANAS         OCAÑA
# 3         Acceso Anselma Manrique 177        ANCASH    PALLASCA    SANTA ROSA
# 4       Callejón Jeremías Bastida 773        ANCASH     CORONGO        BAMBAS
# ...                               ...           ...         ...           ...
# 49995         Glorieta Rafa Olivé 300      AREQUIPA  CONDESUYOS      CAYARANI
# 49996     Alameda Evaristo Hierro 154      AREQUIPA    LA UNION     TOMEPAMPA
# 49997          Via Lázaro Bonilla 488   LA LIBERTAD    TRUJILLO        LAREDO
# 49998   Cañada de Desiderio Pedro 999        LORETO    PUTUMAYO  ROSA PANDURO
# 49999     Cuesta de Ovidio Segura 683  HUANCAVELICA    ACOBAMBA          ANTA
#
# [50000 rows x 4 columns]
